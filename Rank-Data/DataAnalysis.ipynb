# %%
file = open("data/Example 1 - Conic+Line.data", "r")

# %%
data = file.read()

# %%
data.split("\n")
# Out:
# ['# prime, picard number, disc, P2, usertime',
#  '7, 4, -11, [558545864083284007 159584532595224002 32568271958208980 4652610279744140 432028097404813 23737807549715 -3391115364245 -1065779114477 -235301882417 -41523861603 -6496930727 -928132961 -121060821 -14000231 -1294139 -84035 12005 4459 980 140 14 1], 196.22',
#  '11, 4, -679, [7400249944258160101211 -366954542690487277746 -94518594329367935177 4043576227994350168 551396758362865932 -4177248169415651 -4177248169415651 0 21968998637047 570623341222 -129687123005 -11789738455 428717762 136410197 0 -1771561 -14641 15972 968 -187 -6 1], 197.21',
#  '13, 2, -3, [247064529073450392704413 0 -1237009476471531324419 164357902468245420727 3992499655099079046 -460673037126816813 31499011085594312 1211500426369012 -23298085122481 -1792160394037 551433967396 42417997492 -815730721 -62748517 19307236 2970344 -257049 13182 3211 -143 0 1], 197.68',
# ...

# %%
import cProfile

# %%
# %runfile ../General-Tools/LazyList.sage
# %runfile ../TS-Methods/MonoidTS.sage
# %runfile ../TS-Methods/RingTS.sage
# %runfile ../Sequence-Methods/Berlekamp.sage
# %runfile ../TS-Methods/ComplexTS.sage

# %%
TS = ComplexTannakianSymbols()
ts = TS.parseSymbol

# %%
def testTS():
    print TS.getTSFromBellCoeffs(ts("{1, 2, 4}/{3, -3}").getBellCoefficients(), 20)

# %%
testTS()
# Out:
# {1.00000000000000, 2.00000000000000, 4.00000000000000}/{3.00000000000000, -3.00000000000000}

# %%
pr = cProfile.Profile()
pr.enable()

testTS()

pr.disable()
pr.print_stats(sort='time')
# Out:
# {1.00000000000000, 2.00000000000000, 4.00000000000000}/{3.00000000000000, -3.00000000000000}
#          18259 function calls (17835 primitive calls) in 0.143 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         7    0.025    0.004    0.083    0.012 {method 'solve_right' of 'sage.matrix.matrix2.Matrix' objects}
#         1    0.016    0.016    0.119    0.119 <string>:70(bmcheck)
#        72    0.016    0.000    0.038    0.001 matrix_space.py:228(__init__)
#       180    0.006    0.000    0.011    0.000 matrix_space.py:1276(matrix)
#      4414    0.005    0.000    0.005    0.000 {isinstance}
#       217    0.005    0.000    0.045    0.000 matrix_space.py:144(__classcall__)
#       190    0.004    0.000    0.004    0.000 {hasattr}
#      2856    0.003    0.000    0.007    0.000 category.py:748(<genexpr>)
#         7    0.003    0.000    0.003    0.000 <string>:59(listmult)
# ...
